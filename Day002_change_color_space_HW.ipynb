# %% [markdown]
# <a href="https://colab.research.google.com/github/kassy75035/Computer-Vision/blob/main/Day002_change_color_space_HW.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 作業
#
# 使用 [Lena](http://optipng.sourceforge.net/pngtech/img/lena.png)
#
# - 改變圖片的 color space (`HLS`, `LAB`) 並呈現

# %%
import cv2
from google.colab.patches import cv2_imshow # for image display

from google.colab import files
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
import matplotlib.pylab as plt
img_path = '/content/gdrive/My Drive/Colab Notebooks/ComputerVision/data/lena.png'

# 以彩色圖片的方式載入
img = cv2.imread(img_path, cv2.IMREAD_COLOR)

plt.imshow(img)
plt.show()

# %%
# BGR轉RGB
imgrgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

plt.imshow(imgrgb)
plt.show()

# %%
# 轉HSV
imghsv = cv2.cvtColor(img, cv2.COLOR_BGR2HSV)

plt.imshow(imghsv)
plt.show()

# %%
# 轉HSL
imghsl = cv2.cvtColor(img, cv2.COLOR_BGR2HLS)

plt.imshow(imghsl)
plt.show()

# %%
# 轉Lab
imglab = cv2.cvtColor(img, cv2.COLOR_BGR2Lab)

plt.imshow(imglab)
plt.show()
